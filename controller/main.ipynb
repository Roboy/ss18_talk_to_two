# %%
import worker as w

# %matplotlib notebook
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.cm as cm
import matplotlib.pyplot as plt
from matplotlib.animation import FuncAnimation

work=w.Worker()
work.run()
# Out:
# Connect to server to get the Access Token
# (200, 'OK')
# Access Token: eyJhbGciOiJodHRwOi8vd3d3LnczLm9yZy8yMDAxLzA0L3htbGRzaWctbW9yZSNobWFjLXNoYTI1NiIsInR5cCI6IkpXVCJ9.....Rwviz65cny3WuCJwCCBUhC95fkjIGa4k_w4hrMBdKPU
# Id receiver waiting for connection...
# Audio receiver waiting for connection...
# <img src="data:image/png;base64,..." width="640">
# ('Id Connection address pos:', ('192.168.178.55', 34112))('Audio Connection address audio:', ('192.168.178.55', 42074))
#
# ('new recording ', 6)
# creating new speaker 1 for recording 6
# ('new recording ', 9)
# creating new speaker 2 for recording 9
#
#
#
# {"version":"3.0","header":{"status":"success","scenario":"ulm","name":"recording stop","lexical":"recording stop","properties":{"requestid":"12a1a38d-34a1-44c6-a1a3-469df67ff0f8","HIGHCONF":"1"}},"results":[{"scenario":"ulm","name":"recording stop","lexical":"recording stop","confidence":"0.8794522","properties":{"HIGHCONF":"1"}}]}
# Bing:recording stop
# Speaker 2: recording stop
#
#
#
# ('succesfully handeld recording ', 9)
# ('new recording ', 10)
# creating new speaker 3 for recording 10
#
#
#
# {"version":"3.0","header":{"status":"success","scenario":"ulm","name":"not perfect but alright","lexical":"not perfect but alright","properties":{"requestid":"d879b274-e63d-4298-bbf9-40c98f0d03c6","HIGHCONF":"1"}},"results":[{"scenario":"ulm","name":"not perfect but alright","lexical":"not perfect but alright","confidence":"0.7654782","properties":{"HIGHCONF":"1"}}]}
# Bing:not perfect but alright
# Speaker 3: not perfect but alright
#
#
#
# ('succesfully handeld recording ', 10)
#
#
#
# {"version":"3.0","header":{"status":"success","scenario":"ulm","name":"just some generic test dialogue","lexical":"just some generic test dialogue","properties":{"requestid":"293c6e46-001f-441e-8186-dc312d671316","HIGHCONF":"1"}},"results":[{"scenario":"ulm","name":"just some generic test dialogue","lexical":"just some generic test dialogue","confidence":"0.8831902","properties":{"HIGHCONF":"1"}}]}
# Bing:just some generic test dialogue
# Speaker 1: just some generic test dialogue
#
#
#
# sending recording 6 to trainer
# ('succesfully handeld recording ', 6)
# ('new recording ', 13)
# preliminary assigning recording 13 to speaker 1
# Id connection closed externally
# Audio connection closed externally
