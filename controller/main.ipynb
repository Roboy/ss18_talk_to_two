# %%
import controller as c

# %matplotlib notebook
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.cm as cm
import matplotlib.pyplot as plt
from matplotlib.animation import FuncAnimation

cntrl=c.Controller()
cntrl.run()
# Out:
# Id receiver waiting for connection...Audio receiver waiting for connection...
# <img src="data:image/png;base64,..." width="640">
# ('Id Connection address pos:', ('192.168.178.55', 59708))
# ('Audio Connection address audio:', ('192.168.178.55', 39644))
# Exception in thread Thread-8:
# Traceback (most recent call last):
#   File "C:\Users\ich\Anaconda3\envs\odas_2.7\lib\threading.py", line 801, in __bootstrap_inner
#     self.run()
#   File "visualizer.py", line 80, in run
#     ax.scatter(plotsources[:,2], plotsources[:,3], plotsources[:,4], s=plotsources[:,5]*150+50, c=plotsources[:,0], cmap=cm.Set1, norm=plt.colors.Normalize(vmin=0, vmax=7))
# AttributeError: 'function' object has no attribute 'Normalize'
# Found new speaker: 1, pos: -0.863000, 0.449000, 0.233000
# Audio connection closed externally
# Id connection closed externally
