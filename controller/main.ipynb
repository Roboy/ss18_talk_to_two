# %%
import worker as w

# %matplotlib notebook
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.cm as cm
import matplotlib.pyplot as plt
from matplotlib.animation import FuncAnimation

work=w.Worker()
work.run()
# Out:
# Id receiver waiting for connection...
# Audio receiver waiting for connection...
# <img src="data:image/png;base64,..." width="640">
# ('Id Connection address pos:', ('192.168.178.55', 33788))
# ('Audio Connection address audio:', ('192.168.178.55', 34966))
# ('new recording ', 4)
# creating new speaker 1 for recording 4
# no response for request 4 in 1 sec -> timeout
# ('succesfully handeld recording ', 4)
# ('new recording ', 7)
# creating new speaker 2 for recording 7
# ('new recording ', 10)
# preliminary assigning recording 10 to speaker 1
# ('succesfully handeld recording ', 7)
# no response for request 10 in 1 sec -> timeout
# ('succesfully handeld recording ', 10)
# ('new recording ', 13)
# preliminary assigning recording 13 to speaker 1
# no response for request 13 in 1 sec -> timeout
# ('succesfully handeld recording ', 13)
# ('new recording ', 15)
# creating new speaker 3 for recording 15
# no response for request 15 in 1 sec -> timeout
# ('succesfully handeld recording ', 15)
# ('new recording ', 18)
# preliminary assigning recording 18 to speaker 3
# no response for request 18 in 1 sec -> timeout
# ('succesfully handeld recording ', 18)
# ('new recording ', 20)
# preliminary assigning recording 20 to speaker 1
# no response for request 20 in 1 sec -> timeout
# ('succesfully handeld recording ', 20)
# ('new recording ', 28)
# preliminary assigning recording 28 to speaker 1
# no response for request 28 in 1 sec -> timeout
# ('succesfully handeld recording ', 28)
# ('new recording ', 30)
# preliminary assigning recording 30 to speaker 1
# no response for request 30 in 1 sec -> timeout
# ('succesfully handeld recording ', 30)
# ('new recording ', 33)
# preliminary assigning recording 33 to speaker 1
# no response for request 33 in 1 sec -> timeout
# ('new recording ', 36)
# preliminary assigning recording 36 to speaker 2
# no response for request 36 in 1 sec -> timeout
# ('succesfully handeld recording ', 36)
# ('new recording ', 38)
# preliminary assigning recording 38 to speaker 2
# no response for request 38 in 1 sec -> timeout
# ('succesfully handeld recording ', 33)
# ('succesfully handeld recording ', 38)
# ('new recording ', 41)
# preliminary assigning recording 41 to speaker 1
# ('new recording ', 42)
# preliminary assigning recording 42 to speaker 2
# no response for request 41 in 1 sec -> timeout
# ('succesfully handeld recording ', 42)
# ('succesfully handeld recording ', 41)
# ('new recording ', 43)
# preliminary assigning recording 43 to speaker 1
# no response for request 43 in 1 sec -> timeout
# ('succesfully handeld recording ', 43)
# ('new recording ', 45)
# preliminary assigning recording 45 to speaker 1
# no response for request 45 in 1 sec -> timeout
# ('succesfully handeld recording ', 45)
# ('new recording ', 47)
# preliminary assigning recording 47 to speaker 1
# no response for request 47 in 1 sec -> timeout
# ('succesfully handeld recording ', 47)
# ('new recording ', 51)
# preliminary assigning recording 51 to speaker 1
# no response for request 51 in 1 sec -> timeout
# ('succesfully handeld recording ', 51)
# ('new recording ', 56)
# preliminary assigning recording 56 to speaker 1
# ('succesfully handeld recording ', 56)
# ('new recording ', 59)
# preliminary assigning recording 59 to speaker 1
# no response for request 59 in 1 sec -> timeout
# ('succesfully handeld recording ', 59)
# ('new recording ', 72)
# creating new speaker 4 for recording 72
# no response for request 72 in 1 sec -> timeout
# ('succesfully handeld recording ', 72)
# ('new recording ', 73)
# preliminary assigning recording 73 to speaker 4
# no response for request 73 in 1 sec -> timeout
# ('succesfully handeld recording ', 73)
# Audio connection closed externally
# Id connection closed externally
