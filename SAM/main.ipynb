# %%
import SAM as s

# %matplotlib notebook
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.cm as cm
import matplotlib.pyplot as plt
from matplotlib.animation import FuncAnimation


if __name__ == "__main__":  
    sam=s.SAM()
    sam.run()
# Out:
# Connect to server to get the Access Token
# (200, 'OK')
# Access Token: eyJhbGciOiJodHRwOi8vd3d3LnczLm9yZy8yMDAxLzA0L3htbGRzaWctbW9yZSNobWFjLXNoYTI1NiIsInR5cCI6IkpXVCJ9.....QzKbr3muSqX7mUUvmCYlxRoKxEFmyULdNIDNPhFaI6g
# Id receiver waiting for connection...
# Audio receiver waiting for connection...
# <img src="data:image/png;base64,..." width="640">
# ('Id Connection address pos:', ('192.168.178.55', 34766))
#  ('Audio Connection address audio:', ('192.168.178.55', 40562))
# ('new recording ', 1)
# creating new speaker 1 for recording 1
# {"version":"3.0","header":{"status":"error","properties":{"requestid":"41c2c00e-7f83-4815-883e-35fa72aaf8d3","NOSPEECH":"1"}}}
# Microsoft Bing Voice Recognition could not understand audio
#
#
#
# Speaker 1: Error
#
#
#
# sending recording 1 to trainer
# ('succesfully handeld recording ', 1)
# ('new recording ', 2)
# creating new speaker 2 for recording 2
# Traceback (most recent call last):
#   File "t2t_stt.py", line 17, in get_text
#     text = self.bing.recognize(audio, language='en-US')
#   File "bing_voice.py", line 158, in recognize
#     if "header" not in result or "lexical" not in result["header"]: raise UnknownValueError()
# UnknownValueError
# {"version":"3.0","header":{"status":"success","scenario":"ulm","name":"test test recording","lexical":"test test recording","properties":{"requestid":"1c30a8ca-61d5-41d4-a3f4-d7df28612823","HIGHCONF":"1"}},"results":[{"scenario":"ulm","name":"test test recording","lexical":"test test recording","confidence":"0.9498742","properties":{"HIGHCONF":"1"}}]}
# Bing:test test recording
#
#
#
# Speaker 2: test test recording
#
#
#
# ('succesfully handeld recording ', 2)
# Audio connection closed externally
# Id connection closed externally
# Merger is stopping as one of the receivers has stopped.
