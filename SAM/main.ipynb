# %%
import SAM as s

# %matplotlib notebook
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.cm as cm
import matplotlib.pyplot as plt
from matplotlib.animation import FuncAnimation


if __name__ == "__main__":  
    sam=s.SAM()
    sam.run()
# Out:
# Connect to server to get the Access Token
# (200, 'OK')
# Access Token: eyJhbGciOiJodHRwOi8vd3d3LnczLm9yZy8yMDAxLzA0L3htbGRzaWctbW9yZSNobWFjLXNoYTI1NiIsInR5cCI6IkpXVCJ9.....WbvUdqvzhbsep-1KvmMhmRUxk9wYGRH2O4LE-YpnDbA
# Id receiver waiting for connection...
# Audio receiver waiting for connection...
# <img src="data:image/png;base64,..." width="640">
# ('Id Connection address pos:', ('192.168.178.55', 56678))('Audio Connection address audio:', ('192.168.178.55', 58684))
#
# ('new recording ', 2)
# creating new speaker 1 for recording 2
# {"version":"3.0","header":{"status":"success","scenario":"ulm","name":"this is a test recording","lexical":"this is a test recording","properties":{"requestid":"c8beb02f-a87d-40b8-9c4d-561c85fac98b","HIGHCONF":"1"}},"results":[{"scenario":"ulm","name":"this is a test recording","lexical":"this is a test recording","confidence":"0.8277797","properties":{"HIGHCONF":"1"}}]}
# Bing:this is a test recording
#
#
#
# Speaker 1: this is a test recording
#
#
#
# sending recording 2 to trainer
# ('succesfully handeld recording ', 2)
# ('new recording ', 3)
# preliminary assigning recording 3 to speaker 1
# {"version":"3.0","header":{"status":"success","scenario":"ulm","name":"nice works very nice","lexical":"nice works very nice","properties":{"requestid":"2e6df5cf-4b90-462e-acc3-eb4c9452a62f","HIGHCONF":"1"}},"results":[{"scenario":"ulm","name":"nice works very nice","lexical":"nice works very nice","confidence":"0.8118274","properties":{"HIGHCONF":"1"}}]}
# Bing:nice works very nice
#
#
#
# Speaker 1: nice works very nice
#
#
#
# ('succesfully handeld recording ', 3)
# ('new recording ', 8)
# creating new speaker 2 for recording 8
# {"version":"3.0","header":{"status":"success","scenario":"ulm","name":"not working anymore I just need to talk very loud","lexical":"not working anymore i just need to talk very loud","properties":{"requestid":"7038b324-8bf5-444e-a5e6-24bd990b703f","HIGHCONF":"1"}},"results":[{"scenario":"ulm","name":"not working anymore I just need to talk very loud","lexical":"not working anymore i just need to talk very loud","confidence":"0.7873933","properties":{"HIGHCONF":"1"}}]}
# Bing:not working anymore i just need to talk very loud
#
#
#
# Speaker 2: not working anymore i just need to talk very loud
#
#
#
# ('succesfully handeld recording ', 8)
# ('new recording ', 9)
# preliminary assigning recording 9 to speaker 1
# {"version":"3.0","header":{"status":"error","properties":{"requestid":"404dda3f-db3b-44f2-9e15-379ef6d16ddd","NOSPEECH":"1"}}}
# Microsoft Bing Voice Recognition could not understand audio
#
#
#
# Speaker 1: Error
#
#
#
# ('succesfully handeld recording ', 9)
# Traceback (most recent call last):
#   File "t2t_stt.py", line 21, in get_text
#     text = self.bing.recognize(audio, language='en-US')
#   File "bing_voice.py", line 159, in recognize
#     if "header" not in result or "lexical" not in result["header"]: raise UnknownValueError()
# UnknownValueError
# Id connection closed externally
# Audio connection closed externally
# Merger is stopping as one of the receivers has stopped.
# SAM is done.
